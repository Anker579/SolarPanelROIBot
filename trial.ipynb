# %% [markdown]
# ## Trial File to make sure repository git pull/commit is working and google solar API testing

# %% [markdown]
# ### Importing

# %%
import yfinance as yf
import datetime as dt
import pandas as pd
import os
from dotenv import load_dotenv
import googleapiclient.discovery
import requests

# %% [markdown]
# ### Load Environment Variables

# %%
load_dotenv()
GEOCODE_API_KEY = os.getenv("GEOCODING_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("API key not found. Make sure you have a .env file with GOOGLE_API_KEY set.")

# %% [markdown]
# ### First Attempt: Gemini suggested
# Generates a "service" to be used with requests - I don't understand this too much, seems to harder to manipulate the request.

# %%
# The service and version of the API
api_service_name = "solar"
api_version = "v1"

# The location for which to get solar data
# Replace with the desired latitude and longitude
latitude = 52.267142
longitude = -0.756885

#url = f"https://solar.googleapis.com/v1/buildingInsights:findClosest?key={GOOGLE_API_KEY}&latitude={latitude}&longitude={longitude}"

# %%
try:
    # Build the service object
    service = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=GOOGLE_API_KEY
    )

    # The specific API call for building insights
    request = service.buildingInsights().findClosest(
        location_latitude=latitude, location_longitude=longitude
    )

    # Execute the request
    response = request.execute()
    
    # Print the response
    print(response)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: <HttpError 404 when requesting https://solar.googleapis.com/v1/buildingInsights:findClosest?location.latitude=52.267142&location.longitude=-0.756885&key=AIzaSyCcmTlOT2f62hHpj8hXV5p6JmxYNsqbS-0&alt=json returned "Requested entity was not found.". Details: "Requested entity was not found.">

# %% [markdown]
# ### Using URL Request

# %%
import os
import googleapiclient.discovery
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get your API key from the environment variable
api_key = os.getenv("GOOGLE_API_KEY")

# Check if the API key is available
if not api_key:
    raise ValueError("API key not found. Make sure you have a .env file with GOOGLE_API_KEY set.")

# The service and version of the API
api_service_name = "solar"
api_version = "v1"

# The location for which to get solar data
# Replace with the desired latitude and longitude
latitude = 52.2661775
longitude = -0.7577842
#longitude = -0.770228

def get_solar_data1(lat, lon):
    """
    Calls the Google Solar API to get building insights for a given location.
    """
    try:
        # Build the service object
        service = googleapiclient.discovery.build(
            api_service_name, api_version, developerKey=api_key
        )

        # The specific API call for building insights
        request = service.buildingInsights().findClosest(
            location_latitude=lat, location_longitude=lon
        )
        
        # Execute the request
        response = request.execute()

        # Print the response
        return response
    except Exception as e:
        print(f"An error occurred: {e}")

def get_solar_data2(lat, long):
    solar_url = f"https://solar.googleapis.com/v1/buildingInsights:findClosest?location.latitude={lat}&location.longitude={long}&requiredQuality=MEDIUM&key={GOOGLE_API_KEY}"
    response1 = requests.get(url=solar_url)
    return response1


print("Hello")
if __name__ == "__main__":
    res = get_solar_data2(latitude, longitude)
    print(res.text)
# Out:
# Hello
# {
#   "name": "buildings/ChIJP8M9H0mnd0gRPlBE-D1UtkU",
#   "center": {
#     "latitude": 52.2660902,
#     "longitude": -0.75731339999999991
#   },
#   "imageryDate": {
#     "year": 2020,
#     "month": 5,
#     "day": 31
#   },
#   "regionCode": "GB",
#   "solarPotential": {
#     "maxArrayPanelsCount": 50,
#     "maxArrayAreaMeters2": 98.17774,
#     "maxSunshineHoursPerYear": 1040.9915,
#     "carbonOffsetFactorKgPerMwh": 478.99942,
#     "wholeRoofStats": {
#       "areaMeters2": 166.61783,
#       "sunshineQuantiles": [
#         327.10767,
#         594.6463,
#         738.63715,
#         825.9366,
#         852.8551,
#         872.2024,
#         936.007,
#         972.789,
#         987.53864,
#         1005.9273,
#         1069.2009
#       ],
#       "groundAreaMeters2": 159.11
#     },
#     "roofSegmentStats": [
#       {
#         "pitchDegrees": 1.3813082,
#         "azimuthDegrees": 311.7388,
#         "stats": {
#           "areaMeters2": 119.92486,
#           "sunshineQuantiles": [
#             327.10767,
#             619.21594,
#             782.91095,
#             834.76184,
#             853.29974,
#             868.4598,
#             909.2063,
#             963.95746,
#             981.3562,
#             989.9069,
#             1066.425
#           ],
#           "groundAreaMeters2": 119.89001
#         },
#         "center": {
#           "latitude": 52.2660964,
#           "longitude": -0.75735409999999992
#         },
#         "boundingBox": {
#           "sw": {
#             "latitude": 52.2660136,
#             "longitude": -0.75743949999999993
#           },
#           "ne": {
#             "latitude": 52.2661739,
#             "longitude": -0.7572705
#           }
#         },
#         "planeHeightAtCenterMeters": 95.05719
#       },
#       {
#         "pitchDegrees": 29.902636,
#         "azimuthDegrees": 187.56622,
#         "stats": {
#           "areaMeters2": 15.100237,
#           "sunshineQuantiles": [
#             723.45044,
#             906.24316,
#             955.67865,
#             988.5667,
#             1006.2296,
#             1017.87756,
#             1024.8267,
#             1029.8523,
#             1033.668,
#             1042.0016,
#             1069.2009
#           ],
#           "groundAreaMeters2": 13.09
#         },
#         "center": {
#           "latitude": 52.2660511,
#           "longitude": -0.7572861
#         },
#         "boundingBox": {
#           "sw": {
#             "latitude": 52.2660328,
#             "longitude": -0.7573184
#           },
#           "ne": {
#             "latitude": 52.266070100000007,
#             "longitude": -0.75724629999999993
#           }
#         },
#         "planeHeightAtCenterMeters": 94.031845
#       },
#       {
#         "pitchDegrees": 41.193462,
#         "azimuthDegrees": 13.779267,
#         "stats": {
#           "areaMeters2": 17.435446,
#           "sunshineQuantiles": [
#             431.34027,
#             489.39725,
#             562.9248,
#             605.34985,
#             620.1436,
#             629.20056,
#             636.90784,
#             659.1756,
#             709.0066,
#             819.76965,
#             994.9428
#           ],
#           "groundAreaMeters2": 13.120001
#         },
#         "center": {
#           "latitude": 52.266076,
#           "longitude": -0.757276
#         },
#         "boundingBox": {
#           "sw": {
#             "latitude": 52.2660596,
#             "longitude": -0.75731710000000008
#           },
#           "ne": {
#             "latitude": 52.266095199999995,
#             "longitude": -0.7572378
#           }
#         },
#         "planeHeightAtCenterMeters": 93.81367
#       },
#       {
#         "pitchDegrees": 23.225275,
#         "azimuthDegrees": 201.3116,
#         "stats": {
#           "areaMeters2": 14.157287,
#           "sunshineQuantiles": [
#             358.5287,
#             521.27094,
#             801.9412,
#             887.0262,
#             950.2511,
#             996.8279,
#             1007.1941,
#             1014.65845,
#             1021.4968,
#             1027.1434,
#             1052.5604
#           ],
#           "groundAreaMeters2": 13.01
#         },
#         "center": {
#           "latitude": 52.2661393,
#           "longitude": -0.7572464
#         },
#         "boundingBox": {
#           "sw": {
#             "latitude": 52.2661221,
#             "longitude": -0.75727729999999993
#           },
#           "ne": {
#             "latitude": 52.2661592,
#             "longitude": -0.7572125
#           }
#         },
#         "planeHeightAtCenterMeters": 94.0101
#       }
#     ],
#     "solarPanelConfigs": [
#       {
#         "panelsCount": 4,
#         "yearlyEnergyDcKwh": 1647.5162,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1240.0294,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 1,
#             "yearlyEnergyDcKwh": 407.48688,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 5,
#         "yearlyEnergyDcKwh": 2054.7114,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1240.0294,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 2,
#             "yearlyEnergyDcKwh": 814.6819,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 6,
#         "yearlyEnergyDcKwh": 2457.4497,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1642.7678,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 2,
#             "yearlyEnergyDcKwh": 814.6819,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 7,
#         "yearlyEnergyDcKwh": 2858.5618,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1642.7678,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1215.7938,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 8,
#         "yearlyEnergyDcKwh": 3255.863,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 1,
#             "yearlyEnergyDcKwh": 397.30145,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1642.7678,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1215.7938,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 9,
#         "yearlyEnergyDcKwh": 3652.4382,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 1,
#             "yearlyEnergyDcKwh": 397.30145,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1215.7938,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 10,
#         "yearlyEnergyDcKwh": 4048.6536,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 1,
#             "yearlyEnergyDcKwh": 397.30145,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 11,
#         "yearlyEnergyDcKwh": 4441.4775,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 2,
#             "yearlyEnergyDcKwh": 790.1254,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 12,
#         "yearlyEnergyDcKwh": 4837.699,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 1186.3469,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 13,
#         "yearlyEnergyDcKwh": 5233.4717,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1582.1196,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 14,
#         "yearlyEnergyDcKwh": 5629.526,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 1978.1737,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 15,
#         "yearlyEnergyDcKwh": 6022.3125,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 6,
#             "yearlyEnergyDcKwh": 2370.9602,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 16,
#         "yearlyEnergyDcKwh": 6416.943,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 7,
#             "yearlyEnergyDcKwh": 2765.5908,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 17,
#         "yearlyEnergyDcKwh": 6809.6304,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 8,
#             "yearlyEnergyDcKwh": 3158.2778,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 18,
#         "yearlyEnergyDcKwh": 7201.655,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 9,
#             "yearlyEnergyDcKwh": 3550.3025,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 19,
#         "yearlyEnergyDcKwh": 7590.721,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 10,
#             "yearlyEnergyDcKwh": 3939.3691,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 20,
#         "yearlyEnergyDcKwh": 7979.0376,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 11,
#             "yearlyEnergyDcKwh": 4327.6855,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 21,
#         "yearlyEnergyDcKwh": 8359.613,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 12,
#             "yearlyEnergyDcKwh": 4708.2607,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 22,
#         "yearlyEnergyDcKwh": 8740.543,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 13,
#             "yearlyEnergyDcKwh": 5089.191,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 23,
#         "yearlyEnergyDcKwh": 9111.703,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 14,
#             "yearlyEnergyDcKwh": 5460.351,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 24,
#         "yearlyEnergyDcKwh": 9501.455,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 15,
#             "yearlyEnergyDcKwh": 5850.1035,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 25,
#         "yearlyEnergyDcKwh": 9890.549,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 16,
#             "yearlyEnergyDcKwh": 6239.1973,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 26,
#         "yearlyEnergyDcKwh": 10245.794,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 17,
#             "yearlyEnergyDcKwh": 6594.442,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 27,
#         "yearlyEnergyDcKwh": 10595.102,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 18,
#             "yearlyEnergyDcKwh": 6943.7495,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 28,
#         "yearlyEnergyDcKwh": 10940.561,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 19,
#             "yearlyEnergyDcKwh": 7289.2085,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 29,
#         "yearlyEnergyDcKwh": 11281.494,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 20,
#             "yearlyEnergyDcKwh": 7630.1426,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 30,
#         "yearlyEnergyDcKwh": 11629.668,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 21,
#             "yearlyEnergyDcKwh": 7978.3154,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 31,
#         "yearlyEnergyDcKwh": 11975.345,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 22,
#             "yearlyEnergyDcKwh": 8323.993,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 32,
#         "yearlyEnergyDcKwh": 12315.098,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 23,
#             "yearlyEnergyDcKwh": 8663.746,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 33,
#         "yearlyEnergyDcKwh": 12654.513,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 24,
#             "yearlyEnergyDcKwh": 9003.161,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 34,
#         "yearlyEnergyDcKwh": 12992.272,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 25,
#             "yearlyEnergyDcKwh": 9340.921,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 35,
#         "yearlyEnergyDcKwh": 13334.444,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 26,
#             "yearlyEnergyDcKwh": 9683.093,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 36,
#         "yearlyEnergyDcKwh": 13670.52,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 27,
#             "yearlyEnergyDcKwh": 10019.168,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 37,
#         "yearlyEnergyDcKwh": 14003.544,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 28,
#             "yearlyEnergyDcKwh": 10352.192,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 38,
#         "yearlyEnergyDcKwh": 14334.529,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 29,
#             "yearlyEnergyDcKwh": 10683.178,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 39,
#         "yearlyEnergyDcKwh": 14649.152,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 30,
#             "yearlyEnergyDcKwh": 10997.801,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 40,
#         "yearlyEnergyDcKwh": 14963.577,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 31,
#             "yearlyEnergyDcKwh": 11312.227,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 41,
#         "yearlyEnergyDcKwh": 15297.768,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 32,
#             "yearlyEnergyDcKwh": 11646.417,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 42,
#         "yearlyEnergyDcKwh": 15639.046,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 33,
#             "yearlyEnergyDcKwh": 11987.695,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 43,
#         "yearlyEnergyDcKwh": 15975.673,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 34,
#             "yearlyEnergyDcKwh": 12324.322,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 44,
#         "yearlyEnergyDcKwh": 16296.631,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 45,
#         "yearlyEnergyDcKwh": 16565.984,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 1,
#             "yearlyEnergyDcKwh": 269.35458,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 46,
#         "yearlyEnergyDcKwh": 16831.006,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 2,
#             "yearlyEnergyDcKwh": 534.3746,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 47,
#         "yearlyEnergyDcKwh": 17090.754,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 3,
#             "yearlyEnergyDcKwh": 794.1236,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 48,
#         "yearlyEnergyDcKwh": 17342.889,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1046.2573,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 49,
#         "yearlyEnergyDcKwh": 17584.691,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 1288.0609,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       },
#       {
#         "panelsCount": 50,
#         "yearlyEnergyDcKwh": 17822.695,
#         "roofSegmentSummaries": [
#           {
#             "pitchDegrees": 1.3813082,
#             "azimuthDegrees": 311.7388,
#             "panelsCount": 35,
#             "yearlyEnergyDcKwh": 12645.279,
#             "segmentIndex": 0
#           },
#           {
#             "pitchDegrees": 29.902636,
#             "azimuthDegrees": 187.56622,
#             "panelsCount": 5,
#             "yearlyEnergyDcKwh": 2039.3429,
#             "segmentIndex": 1
#           },
#           {
#             "pitchDegrees": 41.193462,
#             "azimuthDegrees": 13.779267,
#             "panelsCount": 6,
#             "yearlyEnergyDcKwh": 1526.0652,
#             "segmentIndex": 2
#           },
#           {
#             "pitchDegrees": 23.225275,
#             "azimuthDegrees": 201.3116,
#             "panelsCount": 4,
#             "yearlyEnergyDcKwh": 1612.0092,
#             "segmentIndex": 3
#           }
#         ]
#       }
#     ],
#     "panelCapacityWatts": 400,
#     "panelHeightMeters": 1.879,
#     "panelWidthMeters": 1.045,
#     "panelLifetimeYears": 20,
#     "buildingStats": {
#       "areaMeters2": 260.97202,
#       "sunshineQuantiles": [
#         323.43088,
#         550.10406,
#         672.0834,
#         775.72766,
#         833.36,
#         860.40656,
#         895.1661,
#         960.9212,
#         985.33105,
#         1004.5523,
#         1072.6235
#       ],
#       "groundAreaMeters2": 219.89
#     },
#     "solarPanels": [
#       {
#         "center": {
#           "latitude": 52.266048299999994,
#           "longitude": -0.7572727
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 414.82858,
#         "segmentIndex": 1
#       },
#       {
#         "center": {
#           "latitude": 52.2660564,
#           "longitude": -0.7572705
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 414.55588,
#         "segmentIndex": 1
#       },
#       {
#         "center": {
#           "latitude": 52.2660591,
#           "longitude": -0.7572977
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 410.64496,
#         "segmentIndex": 1
#       },
#       {
#         "center": {
#           "latitude": 52.2661324,
#           "longitude": -0.7572373
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 407.48688,
#         "segmentIndex": 3
#       },
#       {
#         "center": {
#           "latitude": 52.266140400000005,
#           "longitude": -0.75723180000000012
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 407.19504,
#         "segmentIndex": 3
#       },
#       {
#         "center": {
#           "latitude": 52.2660511,
#           "longitude": -0.7572998
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 402.7384,
#         "segmentIndex": 1
#       },
#       {
#         "center": {
#           "latitude": 52.266147,
#           "longitude": -0.7572571
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 401.11194,
#         "segmentIndex": 3
#       },
#       {
#         "center": {
#           "latitude": 52.2661066,
#           "longitude": -0.7573212
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 397.30145,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660403,
#           "longitude": -0.75727479999999991
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 396.5751,
#         "segmentIndex": 1
#       },
#       {
#         "center": {
#           "latitude": 52.266139,
#           "longitude": -0.7572626
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 396.21533,
#         "segmentIndex": 3
#       },
#       {
#         "center": {
#           "latitude": 52.2661002,
#           "longitude": -0.7573101
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 392.824,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266087899999995,
#           "longitude": -0.7573291
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 396.22153,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660757,
#           "longitude": -0.757348
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 395.7727,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660692,
#           "longitude": -0.7573369
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 396.05402,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266056999999996,
#           "longitude": -0.7573559
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 392.7866,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660505,
#           "longitude": -0.75734479999999993
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 394.6307,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660815,
#           "longitude": -0.75731799999999994
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 392.68713,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266094400000007,
#           "longitude": -0.7573402
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 392.02457,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661189,
#           "longitude": -0.7573023
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 389.0666,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266044,
#           "longitude": -0.7573337
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 388.31616,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660318,
#           "longitude": -0.75735259999999993
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 380.5754,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266025299999995,
#           "longitude": -0.7573415
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 380.93,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661254,
#           "longitude": -0.75731339999999991
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 371.16013,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266137600000008,
#           "longitude": -0.75729439999999992
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 389.7523,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661441,
#           "longitude": -0.7573055
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 389.09363,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660383,
#           "longitude": -0.7573637
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 355.24466,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660699,
#           "longitude": -0.75737809999999994
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 349.30768,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266076399999996,
#           "longitude": -0.7573892
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 345.45898,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660828,
#           "longitude": -0.75740029999999992
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 340.93423,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660951,
#           "longitude": -0.75738129999999992
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 348.173,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661015,
#           "longitude": -0.7573924
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 345.67734,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266064099999994,
#           "longitude": -0.75740809999999992
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 339.75305,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266057599999996,
#           "longitude": -0.757397
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 339.41513,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661138,
#           "longitude": -0.75737349999999992
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 337.75967,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661203,
#           "longitude": -0.7573846
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 342.1716,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266051200000007,
#           "longitude": -0.7573859
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 336.07504,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266045399999996,
#           "longitude": -0.757416
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 333.0245,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266088599999996,
#           "longitude": -0.7573702
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 330.98538,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2660389,
#           "longitude": -0.75740489999999994
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 314.62256,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661325,
#           "longitude": -0.7573656
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 314.4257,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266139,
#           "longitude": -0.7573767
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 334.1905,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266151199999996,
#           "longitude": -0.75735769999999991
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 341.278,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266157700000008,
#           "longitude": -0.7573688
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 336.62717,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.2661447,
#           "longitude": -0.7573466
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 320.9572,
#         "segmentIndex": 0
#       },
#       {
#         "center": {
#           "latitude": 52.266070299999996,
#           "longitude": -0.7572905
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 269.35458,
#         "segmentIndex": 2
#       },
#       {
#         "center": {
#           "latitude": 52.2660658,
#           "longitude": -0.75726399999999994
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 265.02,
#         "segmentIndex": 2
#       },
#       {
#         "center": {
#           "latitude": 52.2660772,
#           "longitude": -0.75728739999999994
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 259.749,
#         "segmentIndex": 2
#       },
#       {
#         "center": {
#           "latitude": 52.2660726,
#           "longitude": -0.75726090000000013
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 252.13377,
#         "segmentIndex": 2
#       },
#       {
#         "center": {
#           "latitude": 52.266084,
#           "longitude": -0.75728429999999991
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 241.80362,
#         "segmentIndex": 2
#       },
#       {
#         "center": {
#           "latitude": 52.266079399999995,
#           "longitude": -0.7572578
#         },
#         "orientation": "LANDSCAPE",
#         "yearlyEnergyDcKwh": 238.00429,
#         "segmentIndex": 2
#       }
#     ]
#   },
#   "boundingBox": {
#     "sw": {
#       "latitude": 52.266009000000004,
#       "longitude": -0.7574396000000001
#     },
#     "ne": {
#       "latitude": 52.2661739,
#       "longitude": -0.757168
#     }
#   },
#   "imageryQuality": "MEDIUM",
#   "imageryProcessedDate": {
#     "year": 2025,
#     "month": 4,
#     "day": 15
#   }
# }

# %% [markdown]
# ### Geocoding Request

# %% [markdown]
# #### Using a generic geocoding API

# %%
x = "34 Northampton Road, Earls Barton, UK, NN60HA"
y = "Northampton, UK"
inputted_address = x

geocode_url = f"https://geocode.maps.co/search?q={inputted_address}&api_key={GEOCODE_API_KEY}"

lat_long_response = requests.get(geocode_url)
print(lat_long_response.text)
# Out:
# [{"place_id":247867770,"licence":"Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright","osm_type":"way","osm_id":991573254,"boundingbox":["52.2660547","52.2661775","-0.7579467","-0.7577842"],"lat":"52.2661775","lon":"-0.7577842","display_name":"Northampton Road, Earls Barton, North Northamptonshire, England, NN6 0HA, United Kingdom","class":"highway","type":"secondary","importance":0.50001}]

# %% [markdown]
# #### Using the Google Geocoding API

# %%
x = "34 Northampton Road, Earls Barton, UK, NN60HA"
y = "Northampton, UK"
inputted_address = x

google_geocode_url = f"https://maps.googleapis.com/maps/api/geocode/json?address=34+Northampton+Road,+Earls+Barton,+UK&key={GOOGLE_API_KEY}"
